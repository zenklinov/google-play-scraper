# %% [markdown]
# ## Install & Import Dependencies
# - Install required libraries: `pandas` and `google-play-scraper`.
# - Import necessary modules for:
#   - **Scraping** reviews (`google-play-scraper`).

# %%
# Install required libraries (if not installed)
# !pip install pandas google-play-scraper

# Import necessary libraries
from urllib.parse import urlparse, parse_qs
from google_play_scraper import reviews, Sort
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: google-play-scraper in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (1.2.7)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\amana\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Extract Package Name from Google Play URL
# - This function extracts the package name from a Google Play Store URL.
# - The package name is necessary for fetching app reviews using the `google-play-scraper` library.
# - Example URL: `https://play.google.com/store/apps/details?id=com.ea.game.pvzfree_row`
# - Extracted package name: **`com.ea.game.pvzfree_row`**

# %%
# Function to extract package name from Google Play URL
def get_package_name(play_store_url):
    parsed_url = urlparse(play_store_url)
    query_params = parse_qs(parsed_url.query)
    return query_params.get('id', [None])[0]

# Define Google Play Store URL
url = "https://play.google.com/store/apps/details?id=com.ea.game.pvzfree_row"

# Extract package name
package_name = get_package_name(url)
print("Extracted Package Name:", package_name)
# Out:
# Extracted Package Name: com.ea.game.pvzfree_row

# %% [markdown]
# ## Fetch Google Play Reviews
# - Fetches the latest 200 reviews for the extracted package name.
# - Reviews include metadata like:
#   - **Review content**
#   - **Timestamp**
#   - **Rating (1-5 stars)**
#   - **User information**
# - Converts the reviews into a Pandas DataFrame for easier manipulation.

# %%
# Fetch reviews using the extracted package name
app_reviews, _ = reviews(
    package_name,
    lang='en',   # Language: English
    country='us',  # Country: US
    count=200,   # Fetch 200 reviews to allow filtering
    sort= Sort.NEWEST  # Get the latest reviews
)

# Convert reviews to a DataFrame
df = pd.DataFrame(app_reviews)

# Display
df
# Out:
#                                  reviewId                       userName  \
# 0    ac769863-56f3-4103-85ff-2dd9b2ec8ce8  Mohd Nasarudin Muhammad Nasir
# 1    eb0c29ee-34c9-4ba0-9c94-f0835ba94cb2                        Nichole
# 2    9493d0b5-5ded-4de0-a6b4-359496ffd91a                     george bob
# 3    c453ef78-eabe-4c23-9b8a-b7bbabc981b2                   Lucas Greene
# 4    e4f7fc70-5b76-472d-9af4-416218da3667                Enija Štūlberga
# ..                                    ...                            ...
# 195  6abef3bb-75a8-4134-9e78-f2d2621241af                 Azrael Zachary
# 196  6ce9a73f-05a0-4c5c-a431-6d1ee8e8d3e2                       Ali Amin
# 197  76b4a9c7-f052-44ee-9ade-f3f0f6e1a178                 Melchora Tinga
# 198  2df21880-36d2-4fea-8538-90bd96746b63                 Joseph Lockett
# 199  49ff6552-2883-4333-886d-01357aabd633                 Лейок Параноик
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 195  https://play-lh.googleusercontent.com/a/ACg8oc...
# 196  https://play-lh.googleusercontent.com/a/ACg8oc...
# 197  https://play-lh.googleusercontent.com/a/ACg8oc...
# 198  https://play-lh.googleusercontent.com/a/ACg8oc...
# 199  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0                                                 Good      5              0
# 1    Ever since I paid for no ads, the app freezes ...      4              0
# 2    The ads are unacceptable. I can't let my kid p...      1              0
# 3    Great, even in 2025. This game I have played q...      5              0
# 4    Too laggy. I'm not picky in games, still play ...      1              0
# ..                                                 ...    ...            ...
# 195  Absoluty Good! Planting Sunflowers! Peashooter...      5              0
# 196  1. Adventure 2 Zomboss level too difficult and...      1              1
# 197    It is a really amazing game for kids or adults.      5              0
# 198  So like why did y'all delete my progress 😕... ...      1              1
# 199                       Прекраснейшый Tower Defense!      5              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                   None 2025-02-24 08:19:12         None      None       None
# 1                  3.8.1 2025-02-24 07:58:15         None      None      3.8.1
# 2                   None 2025-02-24 07:30:35         None      None       None
# 3                  3.8.1 2025-02-24 04:55:19         None      None      3.8.1
# 4                   None 2025-02-24 04:20:58         None      None       None
# ..                   ...                 ...          ...       ...        ...
# 195                3.8.1 2025-02-16 12:22:50         None      None      3.8.1
# 196                3.8.1 2025-02-16 12:18:03         None      None      3.8.1
# 197                 None 2025-02-16 11:19:57         None      None       None
# 198                3.8.1 2025-02-16 11:08:30         None      None      3.8.1
# 199                 None 2025-02-16 11:01:00         None      None       None
#
# [200 rows x 11 columns]

# %% [markdown]
# ## Filter Required Columns
# - Select only the following columns from the DataFrame:
#   - **`reviewId`** → Unique ID for each review.
#   - **`content`** → The actual review content written by the user.
#   - **`score`** → The rating given by the user (1-5).
# - Uses **Pandas** to display only relevant columns.

# %%
# Select only the required columns: 'reviewId', 'content', and 'score'
df_filtered_columns = df[['reviewId', 'content', 'score']]

# Display the result
df_filtered_columns
# Out:
#                                  reviewId  \
# 0    ac769863-56f3-4103-85ff-2dd9b2ec8ce8
# 1    eb0c29ee-34c9-4ba0-9c94-f0835ba94cb2
# 2    9493d0b5-5ded-4de0-a6b4-359496ffd91a
# 3    c453ef78-eabe-4c23-9b8a-b7bbabc981b2
# 4    e4f7fc70-5b76-472d-9af4-416218da3667
# ..                                    ...
# 195  6abef3bb-75a8-4134-9e78-f2d2621241af
# 196  6ce9a73f-05a0-4c5c-a431-6d1ee8e8d3e2
# 197  76b4a9c7-f052-44ee-9ade-f3f0f6e1a178
# 198  2df21880-36d2-4fea-8538-90bd96746b63
# 199  49ff6552-2883-4333-886d-01357aabd633
#
#                                                content  score
# 0                                                 Good      5
# 1    Ever since I paid for no ads, the app freezes ...      4
# 2    The ads are unacceptable. I can't let my kid p...      1
# 3    Great, even in 2025. This game I have played q...      5
# 4    Too laggy. I'm not picky in games, still play ...      1
# ..                                                 ...    ...
# 195  Absoluty Good! Planting Sunflowers! Peashooter...      5
# 196  1. Adventure 2 Zomboss level too difficult and...      1
# 197    It is a really amazing game for kids or adults.      5
# 198  So like why did y'all delete my progress 😕... ...      1
# 199                       Прекраснейшый Tower Defense!      5
#
# [200 rows x 3 columns]
